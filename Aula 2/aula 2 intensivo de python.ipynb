# %%
#Passo 1: Importa a base de dados
import pandas as pd

tabela = pd.read_csv("telecom_users.csv")

#Passo 2: Visualizar a base de dados
tabela = tabela.drop("Unnamed: 0", axis=1)
tabela = tabela.drop("IDCliente", axis=1)
display(tabela)
# - Entender quais as informações tão disponiveis 
# - Descobrir as cagadas da base de dados
# Out:
#          Genero  Aposentado Casado Dependentes  MesesComoCliente  \
# 0     Masculino           0    Sim         Sim                72
# 1      Feminino           0    Nao         Nao                44
# 2      Feminino           1    Sim         Nao                38
# 3     Masculino           0    Nao         Nao                 4
# 4     Masculino           0    Nao         Nao                 2
# ...         ...         ...    ...         ...               ...
# 5981  Masculino           0    Sim         Nao                 1
# 5982   Feminino           0    Sim         Sim                23
# 5983  Masculino           0    Sim         Sim                12
# 5984  Masculino           1    Nao         Nao                12
# 5985  Masculino           0    Nao         Nao                26
#
#      ServicoTelefone MultiplasLinhas ServicoInternet ServicoSegurancaOnline  \
# 0                Sim             Sim             Nao            SemInternet
# 1                Sim             Nao           Fibra                    Nao
# 2                Sim             Sim           Fibra                    Nao
# 3                Sim             Nao             DSL                    Nao
# 4                Sim             Nao             DSL                    Sim
# ...              ...             ...             ...                    ...
# 5981             Sim             Nao           Fibra                    Sim
# 5982             Sim             Sim             DSL                    Sim
# 5983             Sim             Nao             Nao            SemInternet
# 5984             Sim             Sim           Fibra                    Nao
# 5985             Sim             Nao             Nao            SemInternet
#
#      ServicoBackupOnline  ... ServicoSuporteTecnico ServicoStreamingTV  \
# 0            SemInternet  ...           SemInternet        SemInternet
# 1                    Sim  ...                   Nao                Sim
# 2                    Nao  ...                   Nao                Nao
# 3                    Nao  ...                   Nao                Nao
# 4                    Nao  ...                   Nao                Nao
# ...                  ...  ...                   ...                ...
# 5981                 Nao  ...                   Nao                Sim
# 5982                 Sim  ...                   Sim                Sim
# 5983         SemInternet  ...           SemInternet        SemInternet
# 5984                 Nao  ...                   Nao                Sim
# 5985         SemInternet  ...           SemInternet        SemInternet
#
#      ServicoFilmes TipoContrato FaturaDigital    FormaPagamento ValorMensal  \
# 0      SemInternet       2 anos           Nao     CartaoCredito       24.10
# 1              Nao       Mensal           Sim     CartaoCredito       88.15
# 2              Nao       Mensal           Sim  DebitoAutomatico       74.95
# 3              Sim       Mensal           Sim  BoletoEletronico       55.90
# 4              Nao       Mensal           Nao  BoletoEletronico       53.45
# ...            ...          ...           ...               ...         ...
# 5981           Sim       Mensal           Sim  BoletoEletronico       95.00
# 5982           Sim       2 anos           Sim     CartaoCredito       91.10
# 5983   SemInternet       Mensal           Sim  BoletoEletronico       21.15
# 5984           Sim       Mensal           Sim  BoletoEletronico       99.45
# 5985   SemInternet        Anual           Nao     CartaoCredito       19.80
#
#       TotalGasto Churn Codigo
# 0        1734.65   Nao    NaN
# 1         3973.2   Nao    NaN
# 2        2869.85   Sim    NaN
# 3          238.5   Nao    NaN
# 4          119.5   Nao    NaN
# ...          ...   ...    ...
# 5981          95   Sim    NaN
# 5982      2198.3   Nao    NaN
# 5983      306.05   Nao    NaN
# 5984     1200.15   Sim    NaN
# 5985       457.3   Nao    NaN
#
# [5986 rows x 21 columns]

# %%
#Passo 3: Tratamento de dados
# - Valores que estão sendo reconhecidos de forma errada
tabela["TotalGasto"] = pd.to_numeric(tabela["TotalGasto"], errors="coerce")

# - Valores vazios
#Deletando as colunas vazias
# axis = 0 _> linha axis = 1 _> coluna
tabela = tabela.dropna(how="all", axis=1)
#Deletando as linhas vazias

print(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5986 entries, 0 to 5985
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Genero                  5986 non-null   object
#  1   Aposentado              5986 non-null   int64
#  2   Casado                  5986 non-null   object
#  3   Dependentes             5985 non-null   object
#  4   MesesComoCliente        5986 non-null   int64
#  5   ServicoTelefone         5986 non-null   object
#  6   MultiplasLinhas         5986 non-null   object
#  7   ServicoInternet         5986 non-null   object
#  8   ServicoSegurancaOnline  5986 non-null   object
#  9   ServicoBackupOnline     5986 non-null   object
#  10  ProtecaoEquipamento     5986 non-null   object
#  11  ServicoSuporteTecnico   5986 non-null   object
#  12  ServicoStreamingTV      5986 non-null   object
#  13  ServicoFilmes           5986 non-null   object
#  14  TipoContrato            5986 non-null   object
#  15  FaturaDigital           5986 non-null   object
#  16  FormaPagamento          5986 non-null   object
#  17  ValorMensal             5986 non-null   float64
#  18  TotalGasto              5976 non-null   float64
#  19  Churn                   5985 non-null   object
# dtypes: float64(2), int64(2), object(16)
# memory usage: 935.4+ KB
# None

# %%
#Passo 4: Análise inicial
# Como estão os nossos cancelamentos?
print(tabela["Churn"].value_counts())
print(tabela["Churn"].value_counts(normalize=True).map("{:.1%}".format))
# Out:
# Nao    4398
# Sim    1587
# Name: Churn, dtype: int64
# Nao    73.5%
# Sim    26.5%
# Name: Churn, dtype: object

# %%
#Passo 5: Análise mais completa
#Comparar cada coluna da minha tabela com  a coluna de cancelamento
import plotly.express as px

#Etapa 1: criar o gráfico 
for coluna in tabela.columns:
    grafico = px.histogram(tabela, x=coluna, color="Churn")
    #Etapa 2: exibir o grafico
    grafico.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-134-b79d21af03a2> in <module>
#       5 #Etapa 1: criar o gráfico
#       6 for coluna in tabela.columns:
# ----> 7     grafico = px.histogram(tabela, x=coluna, color="Churn")
#       8     #Etapa 2: exibir o grafico
#       9     grafico.show()
#
# E:\intencivo de python\lib\site-packages\plotly\express\_chart_types.py in histogram(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, pattern_shape_sequence, pattern_shape_map, marginal, opacity, orientation, barmode, barnorm, histnorm, log_x, log_y, range_x, range_y, histfunc, cumulative, nbins, title, template, width, height)
#     466     `orientation` is `'h'`).
#     467     """
# --> 468     return make_figure(
#     469         args=locals(),
#     470         constructor=go.Histogram,
#
# E:\intencivo de python\lib\site-packages\plotly\express\_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    1974     facet_col_wrap = args.get("facet_col_wrap", 0)
#    1975     for group_name in sorted_group_names:
# -> 1976         group = grouped.get_group(group_name if len(group_name) > 1 else group_name[0])
#    1977         mapping_labels = OrderedDict()
#    1978         trace_name_labels = OrderedDict()
#
# E:\intencivo de python\lib\site-packages\pandas\core\groupby\groupby.py in get_group(self, name, obj)
#     843         inds = self._get_index(name)
#     844         if not len(inds):
# --> 845             raise KeyError(name)
#     846
#     847         return obj._take_with_is_copy(inds, axis=self.axis)
#
# KeyError: (nan, '', '', '', '')
